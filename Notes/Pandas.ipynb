# %%
loc = 'C:\Python\yob\\'
print(loc)
# Out:
# C:\Python\yob\

# %%
import pandas as pd
names1991=pd.read_csv(loc+'yob1991.txt', names = ['names', 'sex', 'births'])

names1991['names']
# Out:
# 0           Ashley
# 1          Jessica
# 2         Brittany
# 3           Amanda
# 4         Samantha
# 5            Sarah
# 6        Stephanie
# 7         Jennifer
# 8        Elizabeth
# 9            Emily
# 10           Megan
# 11           Kayla
# 12          Lauren
# 13          Rachel
# 14          Nicole
# 15           Amber
# 16        Danielle
# 17         Chelsea
# 18        Courtney
# 19         Melissa
# 20         Rebecca
# 21        Michelle
# 22         Heather
# 23         Jasmine
# 24       Katherine
# 25          Kelsey
# 26         Tiffany
# 27        Victoria
# 28          Hannah
# 29          Alyssa
#            ...
# 25076       Yarden
# 25077         Yash
# 25078       Yassin
# 25079    Yehonatan
# 25080      Yehudah
# 25081       Yeison
# 25082       Yianni
# 25083         Yoav
# 25084      Yohance
# 25085        Yonah
# 25086    Yoshihiro
# 25087       Yoshua
# 25088      Yousuke
# 25089      Yovanny
# 25090       Ysmael
# 25091        Yuval
# ...

# %%
names1991.groupby('sex').births.sum()
# Out:
# sex
# F    1874529
# M    2019614
# Name: births, dtype: int64

# %%
pieces=[]

for year in range(1880,2016):
    frame = pd.read_csv(loc+'yob%d.txt' % year, names=['names', 'sex', 'births'])
    frame['year'] = year
    pieces.append(frame)

names = pd.concat(pieces, ignore_index=True)

# %%
total_births = names.pivot_table('births', index = 'year', columns = 'sex', aggfunc = sum)

# %%
total_births = sex.pivot_table('names', index = 'year', columns = '')
# Out:
# sex         F        M
# year
# 1880    90992   110491
# 1881    91953   100743
# 1882   107847   113686
# 1883   112318   104627
# 1884   129020   114443
# 1885   133055   107799
# 1886   144533   110784
# 1887   145981   101415
# 1888   178624   120851
# 1889   178366   110581
# 1890   190376   111025
# 1891   185482   101191
# 1892   212339   122036
# 1893   212905   112317
# 1894   222922   115769
# 1895   233627   117396
# 1896   237918   119567
# 1897   234201   112757
# 1898   258769   122690
# 1899   233023   106211
# 1900   299810   150486
# 1901   239347   106470
# 1902   264076   122659
# 1903   261971   119234
# 1904   275364   128125
# 1905   291622   132315
# 1906   295303   133159
# 1907   318565   146830
# 1908   334313   154339
# 1909   347231   163999
# ...       ...      ...
# 1986  1714905  1840568
# 1987  1738099  1865987
# 1988  1780123  1912979
# 1989  1843219  2000165
# 1990  1897940  2052780
# 1991  1874529  2019614
# 1992  1843446  1996571
# ...

# %%
total_births.tail()
# Out:
# sex         F        M
# year
# 2011  1755278  1895156
# 2012  1756347  1892094
# 2013  1749061  1885683
# 2014  1779496  1913434
# 2015  1776538  1907211

# %%
# Add prop to the Data Frame o.o2 prob means that names is on 2 babies for 100 babies

def add_prop(df):
    births = df.births.astype(float)
    df['prop'] = births / births.sum()
    return df

names = names.groupby(['year', 'sex']).apply(add_prop)

# %%
names.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>names</th>
#       <th>sex</th>
#       <th>births</th>
#       <th>year</th>
#       <th>prop</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Mary</td>
#       <td>F</td>
#       <td>7065</td>
#       <td>1880</td>
#       <td>0.077644</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Anna</td>
#       <td>F</td>
#       <td>2604</td>
#       <td>1880</td>
#       <td>0.028618</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Emma</td>
#       <td>F</td>
#       <td>2003</td>
#       <td>1880</td>
#       <td>0.022013</td>
#     </tr>
#     <tr>
# ...

# %%
np.allclose(names.groupby(['name', 'sex']).prop.sum(),1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d9d46012010a> in <module>()
# ----> 1 np.allclose(names.groupby(['name', 'sex']).prop.sum(),1)
#
# NameError: name 'np' is not defined
